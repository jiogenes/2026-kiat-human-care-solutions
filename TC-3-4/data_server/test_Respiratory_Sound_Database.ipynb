# %%
from scipy.io import wavfile

# %%
DIR = "/data/kiat/respiratory_sound_dataset/respiratory_sound_database/Respiratory_Sound_Database/audio_and_txt_files"

# %%
with open(f"{DIR}/189_1b2_Lr_mc_LittC2SE.txt") as f:
    lines = f.readlines()

# %%
lines
# Out:
# ['0.022\t4.764\t1\t0\n',
#  '4.764\t9.621\t1\t0\n',
#  '9.621\t14.921\t0\t0\n',
#  '14.921\t19.579\t0\t0\n',
#  '19.579\t19.936\t0\t0\n']

# %%
fs, data = wavfile.read(f"{DIR}/189_1b2_Lr_mc_LittC2SE.wav")
